# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./games.csv', error_bad_lines=False)

# %%
df.info()
# null data in price_original and price_discounted
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13469 entries, 0 to 13468
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   app_id            13469 non-null  int64
#  1   title             13469 non-null  object
#  2   date_release      13469 non-null  object
#  3   win               13469 non-null  bool
#  4   mac               13469 non-null  bool
#  5   linux             13469 non-null  bool
#  6   rating            13469 non-null  object
#  7   positive_ratio    13469 non-null  int64
#  8   user_reviews      13469 non-null  int64
#  9   price_final       13469 non-null  float64
#  10  price_original    13443 non-null  float64
#  11  price_discounted  13443 non-null  float64
#  12  discount          13469 non-null  float64
#  13  steam_deck        13469 non-null  bool
# dtypes: bool(4), float64(4), int64(3), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Review of relation between price and positive ratio

# %%
corr = df['positive_ratio'].corr(df['price_original'])
print(corr)

# CORRELATION 
corr_matrix_2=round(df.corr(),2)
corr_matrix_2.style.background_gradient()
# Out:
# -0.1769936088908534
# <style type="text/css">
# #T_8bcc8_row0_col0, #T_8bcc8_row1_col1, #T_8bcc8_row2_col2, #T_8bcc8_row3_col3, #T_8bcc8_row4_col4, #T_8bcc8_row5_col5, #T_8bcc8_row6_col6, #T_8bcc8_row6_col8, #T_8bcc8_row7_col7, #T_8bcc8_row8_col6, #T_8bcc8_row8_col8, #T_8bcc8_row9_col9 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_8bcc8_row0_col1, #T_8bcc8_row4_col6, #T_8bcc8_row4_col8 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_8bcc8_row0_col2, #T_8bcc8_row0_col3, #T_8bcc8_row0_col5, #T_8bcc8_row2_col0, #T_8bcc8_row4_col1, #T_8bcc8_row4_col7, #T_8bcc8_row6_col9, #T_8bcc8_row7_col4, #T_8bcc8_row8_col9, #T_8bcc8_row9_col6, #T_8bcc8_row9_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_8bcc8_row0_col4, #T_8bcc8_row4_col0 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_8bcc8_row0_col6, #T_8bcc8_row0_col8, #T_8bcc8_row3_col9, #T_8bcc8_row5_col2, #T_8bcc8_row7_col9 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_8bcc8_row0_col7, #T_8bcc8_row6_col1, #T_8bcc8_row7_col0, #T_8bcc8_row7_col1, #T_8bcc8_row8_col1, #T_8bcc8_row9_col0 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_8bcc8_row0_col9, #T_8bcc8_row5_col7 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_8bcc8_row0_col10, #T_8bcc8_row1_col10, #T_8bcc8_row2_col10, #T_8bcc8_row3_col10, #T_8bcc8_row4_col10, #T_8bcc8_row5_col10, #T_8bcc8_row6_col10, #T_8bcc8_row7_col10, #T_8bcc8_row8_col10, #T_8bcc8_row9_col10, #T_8bcc8_row10_col0, #T_8bcc8_row10_col1, #T_8bcc8_row10_col2, #T_8bcc8_row10_col3, #T_8bcc8_row10_col4, #T_8bcc8_row10_col5, #T_8bcc8_row10_col6, #T_8bcc8_row10_col7, #T_8bcc8_row10_col8, #T_8bcc8_row10_col9, #T_8bcc8_row10_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_8bcc8_row1_col0, #T_8bcc8_row6_col0, #T_8bcc8_row8_col0, #T_8bcc8_row9_col7 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_8bcc8_row1_col2 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_8bcc8_row1_col3 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_8bcc8_row1_col4 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_8bcc8_row1_col5, #T_8bcc8_row4_col5 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_8bcc8_row1_col6, #T_8bcc8_row1_col8, #T_8bcc8_row5_col6 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_8bcc8_row1_col7, #T_8bcc8_row5_col9 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_8bcc8_row1_col9 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_8bcc8_row2_col1, #T_8bcc8_row4_col3 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_8bcc8_row2_col3 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_8bcc8_row2_col4, #T_8bcc8_row3_col4, #T_8bcc8_row4_col2 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_8bcc8_row2_col5, #T_8bcc8_row3_col5 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_8bcc8_row2_col6, #T_8bcc8_row2_col8, #T_8bcc8_row2_col9, #T_8bcc8_row5_col3 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_8bcc8_row2_col7, #T_8bcc8_row4_col9, #T_8bcc8_row6_col2, #T_8bcc8_row7_col2, #T_8bcc8_row8_col2, #T_8bcc8_row9_col2, #T_8bcc8_row9_col3 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_8bcc8_row3_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_8bcc8_row3_col1, #T_8bcc8_row5_col4 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_8bcc8_row3_col2 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_8bcc8_row3_col6, #T_8bcc8_row3_col8 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_8bcc8_row3_col7 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_8bcc8_row5_col0 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_8bcc8_row5_col1, #T_8bcc8_row9_col1 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_8bcc8_row5_col8 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_8bcc8_row6_col3, #T_8bcc8_row7_col3, #T_8bcc8_row8_col3 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_8bcc8_row6_col4, #T_8bcc8_row8_col4 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_8bcc8_row6_col5 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_8bcc8_row6_col7, #T_8bcc8_row8_col7 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_8bcc8_row7_col5, #T_8bcc8_row8_col5, #T_8bcc8_row9_col4 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_8bcc8_row7_col6, #T_8bcc8_row7_col8 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_8bcc8_row9_col5 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# </style>
# <table id="T_8bcc8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8bcc8_level0_col0" class="col_heading level0 col0" >app_id</th>
#       <th id="T_8bcc8_level0_col1" class="col_heading level0 col1" >win</th>
#       <th id="T_8bcc8_level0_col2" class="col_heading level0 col2" >mac</th>
#       <th id="T_8bcc8_level0_col3" class="col_heading level0 col3" >linux</th>
#       <th id="T_8bcc8_level0_col4" class="col_heading level0 col4" >positive_ratio</th>
#       <th id="T_8bcc8_level0_col5" class="col_heading level0 col5" >user_reviews</th>
#       <th id="T_8bcc8_level0_col6" class="col_heading level0 col6" >price_final</th>
#       <th id="T_8bcc8_level0_col7" class="col_heading level0 col7" >price_original</th>
#       <th id="T_8bcc8_level0_col8" class="col_heading level0 col8" >price_discounted</th>
#       <th id="T_8bcc8_level0_col9" class="col_heading level0 col9" >discount</th>
#       <th id="T_8bcc8_level0_col10" class="col_heading level0 col10" >steam_deck</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bcc8_level0_row0" class="row_heading level0 row0" >app_id</th>
#       <td id="T_8bcc8_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_8bcc8_row0_col1" class="data row0 col1" >-0.030000</td>
#       <td id="T_8bcc8_row0_col2" class="data row0 col2" >-0.180000</td>
#       <td id="T_8bcc8_row0_col3" class="data row0 col3" >-0.160000</td>
#       <td id="T_8bcc8_row0_col4" class="data row0 col4" >0.190000</td>
#       <td id="T_8bcc8_row0_col5" class="data row0 col5" >-0.040000</td>
#       <td id="T_8bcc8_row0_col6" class="data row0 col6" >-0.030000</td>
#       <td id="T_8bcc8_row0_col7" class="data row0 col7" >-0.020000</td>
#       <td id="T_8bcc8_row0_col8" class="data row0 col8" >-0.030000</td>
#       <td id="T_8bcc8_row0_col9" class="data row0 col9" >-0.020000</td>
#       <td id="T_8bcc8_row0_col10" class="data row0 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8bcc8_level0_row1" class="row_heading level0 row1" >win</th>
#       <td id="T_8bcc8_row1_col0" class="data row1 col0" >-0.030000</td>
#       <td id="T_8bcc8_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_8bcc8_row1_col2" class="data row1 col2" >0.090000</td>
#       <td id="T_8bcc8_row1_col3" class="data row1 col3" >0.070000</td>
#       <td id="T_8bcc8_row1_col4" class="data row1 col4" >-0.110000</td>
#       <td id="T_8bcc8_row1_col5" class="data row1 col5" >0.010000</td>
#       <td id="T_8bcc8_row1_col6" class="data row1 col6" >0.040000</td>
#       <td id="T_8bcc8_row1_col7" class="data row1 col7" >0.040000</td>
#       <td id="T_8bcc8_row1_col8" class="data row1 col8" >0.040000</td>
#       <td id="T_8bcc8_row1_col9" class="data row1 col9" >0.010000</td>
#       <td id="T_8bcc8_row1_col10" class="data row1 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8bcc8_level0_row2" class="row_heading level0 row2" >mac</th>
#       <td id="T_8bcc8_row2_col0" class="data row2 col0" >-0.180000</td>
#       <td id="T_8bcc8_row2_col1" class="data row2 col1" >0.090000</td>
#       <td id="T_8bcc8_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_8bcc8_row2_col3" class="data row2 col3" >0.600000</td>
#       <td id="T_8bcc8_row2_col4" class="data row2 col4" >0.050000</td>
#       <td id="T_8bcc8_row2_col5" class="data row2 col5" >0.020000</td>
#       <td id="T_8bcc8_row2_col6" class="data row2 col6" >-0.050000</td>
#       <td id="T_8bcc8_row2_col7" class="data row2 col7" >-0.050000</td>
#       <td id="T_8bcc8_row2_col8" class="data row2 col8" >-0.050000</td>
#       <td id="T_8bcc8_row2_col9" class="data row2 col9" >-0.050000</td>
#       <td id="T_8bcc8_row2_col10" class="data row2 col10" >nan</td>
#     </tr>
