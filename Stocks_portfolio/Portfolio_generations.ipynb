# %%
import itertools
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import csv

# %%
#choose stocks with highest RoE
stocklist = []
stocks_name = []
stocksroe = []

with open ('list_stocks.csv', 'rt') as stocks_csv: #read the companies of s&p 500
    reader = csv.reader(stocks_csv)
    for i in stocks_csv:
        line = i.split(';')
        stocklist.append(line[1].strip())
        stocks_name.append(line[0].strip())

# %%
def generate_combinations(stocks, max_stocks=5):
    combinations = []
    for i in range(100):
        stocks_list = np.random.choice(stocks, max_stocks, replace=False)
        historical_data = yf.download(stocks, start='2018-01-01')
        close_price = historical_data['Close'].pct_change()
        portfolio_return = (close_price * len(stocks_list)).sum(axis=1)
        cumulative_return = (portfolio_return + 1).cumprod()[-1]
        combinations.append((stocks_list, cumulative_return))
    return combinations

# Leer lista de empresas

stocks = stocklist

# Pedir cantidad de combinaciones al usuario
n_combinations = 10

# Generar combinaciones aleatorias y calcular el retorno acumulado
results = []
for i in range(n_combinations):
    combination = generate_combinations(stocks, max_stocks=5)
    results.extend(combination)

# Mostrar resultados
df = pd.DataFrame(results, columns=['Empresas', 'Retorno Acumulado'])
print(df)
# Out:
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# ...

# %%
df.to_csv('./combination_portfolios.csv')
